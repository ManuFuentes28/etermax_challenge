# %%
import pandas as pd
import numpy as np

# %%
FILE = './datos_data_engineer.tsv'
SEP = '\t'
ENCODING = 'utf-16le'

# %%
def read_csv_pandas(filename, sep=',', encoding='utf-8'):
    return pd.read_csv(filename, sep = sep, encoding = encoding)

# %%
df = read_csv_pandas(FILE,SEP,ENCODING)

# %% [markdown]
# # Consideraciones
# * Ver nulos por filas
# * Revisar porcentajes datos validos contra las
# * Archivo de configuracion
# * Hace falta excepciones?
# * Parse para recibir argumentos?
#
# ## Columna ID
# * Ver duplicados
# * Borrar nulos
# * Borrar string
# * Borrar vacios

# %%
df
# Out:
#         id first_name   last_name account_number  \
# 0        1    Addison       Marks         196296
# 1        2     Dakota       Garza         409025
# 2        3      Basia       Wolfe         637720
# 3        4   Germaine    Campbell         826846
# 4        5     Lenore  Pennington         345284
# ...    ...        ...         ...            ...
# 1002   996   Kirestin       Potts         653131
# 1003   997    Kristen       Stout         628705
# 1004   998     Daniel      Snider         535804
# 1005   999     Simone      Mcleod         407847
# 1006  1000   Hermione     Morales         478506
#
#                                         email
# 0                        ornare.lectus@et.edu
# 1              scelerisque@Praesentluctus.edu
# 2                Aliquam@nullaIntegerurna.com
# 3                 id.magna@viverraMaecenas.ca
# 4                         aliquam@Integer.edu
# ...                                       ...
# ...

# %%
df[df["account_number"].duplicated()]["account_number"]
# Out:
# 29        NaN
# 30        NaN
# 83        NaN
# 84        NaN
# 219       NaN
# 341       NaN
# 779       NaN
# 910    973758
# 939    114392
# 990       NaN
# 991       NaN
# Name: account_number, dtype: object

# %%
df.head(50)
# Out:
#         id                 first_name   last_name account_number  \
# 0        1                    Addison       Marks         196296
# 1        2                     Dakota       Garza         409025
# 2        3                      Basia       Wolfe         637720
# 3        4                   Germaine    Campbell         826846
# 4        5                     Lenore  Pennington         345284
# 5        6                      Stacy      Santos         512759
# 6        7                       Jack     Hancock         644688
# 7        8                      Dolan       Colon         969175
# 8        9                        Mia    Johnston         789448
# 9       10                    Malachi   Zimmerman         217250
# 10      11                      Allen        Paul         644841
# 11      12                     Fallon        Dunn         453682
# 12      13                      Donna     Swanson         727124
# ...

# %%
df['id'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1002    False
# 1003    False
# 1004    False
# 1005    False
# 1006    False
# Name: id, Length: 1007, dtype: bool

# %%
df[~df.id.isnull()]
# Out:
#         id first_name   last_name account_number  \
# 0        1    Addison       Marks         196296
# 1        2     Dakota       Garza         409025
# 2        3      Basia       Wolfe         637720
# 3        4   Germaine    Campbell         826846
# 4        5     Lenore  Pennington         345284
# ...    ...        ...         ...            ...
# 1002   996   Kirestin       Potts         653131
# 1003   997    Kristen       Stout         628705
# 1004   998     Daniel      Snider         535804
# 1005   999     Simone      Mcleod         407847
# 1006  1000   Hermione     Morales         478506
#
#                                         email
# 0                        ornare.lectus@et.edu
# 1              scelerisque@Praesentluctus.edu
# 2                Aliquam@nullaIntegerurna.com
# 3                 id.magna@viverraMaecenas.ca
# 4                         aliquam@Integer.edu
# ...                                       ...
# ...

# %%
df[df.id.isnull()]
# Out:
#       id                               first_name               last_name  \
# 30   NaN                ac.ipsum.Phasellus@ut.net                     NaN
# 341  NaN  porttitor.interdum.Sed@Loremipsum.co.uk                     NaN
# 991  NaN                                   157172  enim@disparturient.edu
#
#     account_number email
# 30             NaN   NaN
# 341            NaN   NaN
# 991            NaN   NaN

# %%
df['id'].applymap(np.isreal)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_15897/2153319787.py in <module>
# ----> 1 df['id'].applymap(np.isreal)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'applymap'

# %%
print (df[pd.to_numeric(df['id'], errors='coerce').isnull()]['id'])
# Out:
# 29         Bosley
# 30            NaN
# 84
# 220    Harrington
# 341           NaN
# 780       Barbara
# 991           NaN
# Name: id, dtype: object

# %%
print (df[~pd.to_numeric(df['first_name'], errors='coerce').isnull()])
# Out:
#          id first_name                 last_name account_number email
# 29   Bosley     656184                       NaN            NaN   NaN
# 84              531695  lectus.justo@lorem.co.uk            NaN   NaN
# 991     NaN     157172    enim@disparturient.edu            NaN   NaN

# %% [markdown]
# ## Columna First Name and Last Name
# * Notificar/Borrar numerica
# * Revisar aquellas que sean vacias
# * Notificar/Borrar los que tengan '@'
#
# ## Columna Account Number
# * Ver duplicados
# * Borrar string
# * Borrar vacios
#
# ## Columna email
# * Notificar los que no tengan '@'
# * Notificar los que tengan numeros
# * Notificar los que sean Nan
# * Notificar los que esten vacios
#
# ## Resultado
# * Las columnas se separan con un pipe |
# * Antes de insertarlo a la base calcular porcentaje de la calidad de los datos que llegan
# * UTF-8
